# %% [markdown]
# ## Loading of libraries

# %%
# Load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning
# - Load dataset
# - Check for missing values and datatype
# - Rename columns when necessary
# - Drop unnecessary columns

# %% [markdown]
# #### Load Data

# %%
# Load test data
housing_test = pd.read_csv('../datasets/test.csv')
print(housing_test.shape)
housing_test.head()
# Out:
# (16737, 76)
# /var/folders/w4/cdf3yttj10d7ynthq7lkp5fh0000gn/T/ipykernel_51512/795079612.py:2: DtypeWarning: Columns (40) have mixed types. Specify dtype option on import or set low_memory=False.
#   housing_test = pd.read_csv('../datasets/test.csv')
#        id Tranc_YearMonth         town flat_type block          street_name  \
# 0  114982         2012-11       YISHUN    4 ROOM   173         YISHUN AVE 7
# 1   95653         2019-08  JURONG WEST    5 ROOM  986C    JURONG WEST ST 93
# 2   40303         2013-10   ANG MO KIO    3 ROOM   534    ANG MO KIO AVE 10
# 3  109506         2017-10    WOODLANDS    4 ROOM    29         MARSILING DR
# 4  100149         2016-08  BUKIT BATOK    4 ROOM   170  BT BATOK WEST AVE 8
#
#   storey_range  floor_area_sqm         flat_model  lease_commence_date  ...  \
# 0     07 TO 09            84.0         Simplified                 1987  ...
# 1     04 TO 06           112.0  Premium Apartment                 2008  ...
# 2     07 TO 09            68.0     New Generation                 1980  ...
# 3     01 TO 03            97.0     New Generation                 1979  ...
# 4     16 TO 18           103.0            Model A                 1985  ...
#
#    vacancy  pri_sch_affiliation  pri_sch_latitude  pri_sch_longitude  \
# 0       92                    0          1.433681         103.832924
# 1       45                    0          1.339244         103.698896
# 2       36                    0          1.371893         103.851811
# 3       54                    0          1.434423         103.773698
# 4       40                    0          1.349195         103.741000
#
#    sec_sch_nearest_dist                    sec_sch_name cutoff_point  \
# 0            156.322353  Ahmad Ibrahim Secondary School          218
# 1            739.371688    Jurong West Secondary School          199
# 2            305.071191       Anderson Secondary School          245
# 3            433.454591      Woodlands Secondary School          188
# 4            217.295361    Bukit Batok Secondary School          223
#
#   affiliation  sec_sch_latitude  sec_sch_longitude
# 0           0          1.436235         103.829987
# 1           0          1.335256         103.702098
# 2           0          1.374242         103.851430
# 3           0          1.439183         103.774499
# 4           0          1.348351         103.740873
#
# [5 rows x 76 columns]

# %% [markdown]
# #### Check for missing values and datatype

# %%
housing_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16737 entries, 0 to 16736
# Data columns (total 76 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         16737 non-null  int64
#  1   Tranc_YearMonth            16737 non-null  object
#  2   town                       16737 non-null  object
#  3   flat_type                  16737 non-null  object
#  4   block                      16737 non-null  object
#  5   street_name                16737 non-null  object
#  6   storey_range               16737 non-null  object
#  7   floor_area_sqm             16737 non-null  float64
#  8   flat_model                 16737 non-null  object
#  9   lease_commence_date        16737 non-null  int64
#  10  Tranc_Year                 16737 non-null  int64
#  11  Tranc_Month                16737 non-null  int64
#  12  mid_storey                 16737 non-null  int64
#  13  lower                      16737 non-null  int64
#  14  upper                      16737 non-null  int64
#  15  mid                        16737 non-null  int64
#  16  full_flat_type             16737 non-null  object
#  17  address                    16737 non-null  object
#  18  floor_area_sqft            16737 non-null  float64
#  19  hdb_age                    16737 non-null  int64
#  20  max_floor_lvl              16737 non-null  int64
#  21  year_completed             16737 non-null  int64
#  22  residential                16737 non-null  object
#  23  commercial                 16737 non-null  object
#  24  market_hawker              16737 non-null  object
#  25  multistorey_carpark        16737 non-null  object
#  26  precinct_pavilion          16737 non-null  object
#  27  total_dwelling_units       16737 non-null  int64
#  28  1room_sold                 16737 non-null  int64
#  29  2room_sold                 16737 non-null  int64
#  30  3room_sold                 16737 non-null  int64
#  31  4room_sold                 16737 non-null  int64
#  32  5room_sold                 16737 non-null  int64
#  33  exec_sold                  16737 non-null  int64
#  34  multigen_sold              16737 non-null  int64
#  35  studio_apartment_sold      16737 non-null  int64
#  36  1room_rental               16737 non-null  int64
#  37  2room_rental               16737 non-null  int64
#  38  3room_rental               16737 non-null  int64
#  39  other_room_rental          16737 non-null  int64
#  40  postal                     16737 non-null  object
#  41  Latitude                   16737 non-null  float64
#  42  Longitude                  16737 non-null  float64
#  43  planning_area              16737 non-null  object
#  44  Mall_Nearest_Distance      16653 non-null  float64
#  45  Mall_Within_500m           6445 non-null   float64
#  46  Mall_Within_1km            13951 non-null  float64
#  47  Mall_Within_2km            16524 non-null  float64
#  48  Hawker_Nearest_Distance    16737 non-null  float64
#  49  Hawker_Within_500m         5982 non-null   float64
#  50  Hawker_Within_1km          10008 non-null  float64
#  51  Hawker_Within_2km          13483 non-null  float64
#  52  hawker_food_stalls         16737 non-null  int64
#  53  hawker_market_stalls       16737 non-null  int64
#  54  mrt_nearest_distance       16737 non-null  float64
#  55  mrt_name                   16737 non-null  object
#  56  bus_interchange            16737 non-null  int64
#  57  mrt_interchange            16737 non-null  int64
#  58  mrt_latitude               16737 non-null  float64
#  59  mrt_longitude              16737 non-null  float64
#  60  bus_stop_nearest_distance  16737 non-null  float64
#  61  bus_stop_name              16737 non-null  object
#  62  bus_stop_latitude          16737 non-null  float64
#  63  bus_stop_longitude         16737 non-null  float64
#  64  pri_sch_nearest_distance   16737 non-null  float64
#  65  pri_sch_name               16737 non-null  object
#  66  vacancy                    16737 non-null  int64
#  67  pri_sch_affiliation        16737 non-null  int64
#  68  pri_sch_latitude           16737 non-null  float64
#  69  pri_sch_longitude          16737 non-null  float64
#  70  sec_sch_nearest_dist       16737 non-null  float64
#  71  sec_sch_name               16737 non-null  object
#  72  cutoff_point               16737 non-null  int64
#  73  affiliation                16737 non-null  int64
#  74  sec_sch_latitude           16737 non-null  float64
#  75  sec_sch_longitude          16737 non-null  float64
# dtypes: float64(24), int64(32), object(20)
# memory usage: 9.7+ MB

# %% [markdown]
# There are missing values in `Mall_Nearest_Distance`, `Mall_Within_500m`, `Mall_Within_1km`, `Mall_Within_2km`, `Hawker_Within_500m`, `Hawker_Within_1km`, `Hawker_Within_2km`

# %%
# Change datatype to reflect columns correctly
housing_test['Tranc_YearMonth'] = pd.to_datetime(housing_test['Tranc_YearMonth'])
housing_test['residential'] = housing_test['residential'].map({'Y': True, 'N': False})
housing_test['commercial'] = housing_test['commercial'].map({'Y': True, 'N': False})
housing_test['market_hawker'] = housing_test['market_hawker'].map({'Y': True, 'N': False})
housing_test['multistorey_carpark'] = housing_test['multistorey_carpark'].map({'Y': True, 'N': False})
housing_test['precinct_pavilion'] = housing_test['precinct_pavilion'].map({'Y': True, 'N': False})
housing_test['bus_interchange'] = housing_test['bus_interchange'].map({1: True, 0: False})
housing_test['mrt_interchange'] = housing_test['mrt_interchange'].map({1: True, 0: False})
housing_test['pri_sch_affiliation'] = housing_test['pri_sch_affiliation'].map({1: True, 0: False})
housing_test['affiliation'] = housing_test['affiliation'].map({1: True, 0: False})
housing_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16737 entries, 0 to 16736
# Data columns (total 76 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         16737 non-null  int64
#  1   Tranc_YearMonth            16737 non-null  datetime64[ns]
#  2   town                       16737 non-null  object
#  3   flat_type                  16737 non-null  object
#  4   block                      16737 non-null  object
#  5   street_name                16737 non-null  object
#  6   storey_range               16737 non-null  object
#  7   floor_area_sqm             16737 non-null  float64
#  8   flat_model                 16737 non-null  object
#  9   lease_commence_date        16737 non-null  int64
#  10  Tranc_Year                 16737 non-null  int64
#  11  Tranc_Month                16737 non-null  int64
#  12  mid_storey                 16737 non-null  int64
#  13  lower                      16737 non-null  int64
#  14  upper                      16737 non-null  int64
#  15  mid                        16737 non-null  int64
#  16  full_flat_type             16737 non-null  object
#  17  address                    16737 non-null  object
#  18  floor_area_sqft            16737 non-null  float64
#  19  hdb_age                    16737 non-null  int64
#  20  max_floor_lvl              16737 non-null  int64
#  21  year_completed             16737 non-null  int64
#  22  residential                16737 non-null  bool
#  23  commercial                 16737 non-null  bool
#  24  market_hawker              16737 non-null  bool
#  25  multistorey_carpark        16737 non-null  bool
#  26  precinct_pavilion          16737 non-null  bool
#  27  total_dwelling_units       16737 non-null  int64
#  28  1room_sold                 16737 non-null  int64
#  29  2room_sold                 16737 non-null  int64
#  30  3room_sold                 16737 non-null  int64
#  31  4room_sold                 16737 non-null  int64
#  32  5room_sold                 16737 non-null  int64
#  33  exec_sold                  16737 non-null  int64
#  34  multigen_sold              16737 non-null  int64
#  35  studio_apartment_sold      16737 non-null  int64
#  36  1room_rental               16737 non-null  int64
#  37  2room_rental               16737 non-null  int64
#  38  3room_rental               16737 non-null  int64
#  39  other_room_rental          16737 non-null  int64
#  40  postal                     16737 non-null  object
#  41  Latitude                   16737 non-null  float64
#  42  Longitude                  16737 non-null  float64
#  43  planning_area              16737 non-null  object
#  44  Mall_Nearest_Distance      16653 non-null  float64
#  45  Mall_Within_500m           6445 non-null   float64
#  46  Mall_Within_1km            13951 non-null  float64
#  47  Mall_Within_2km            16524 non-null  float64
#  48  Hawker_Nearest_Distance    16737 non-null  float64
#  49  Hawker_Within_500m         5982 non-null   float64
#  50  Hawker_Within_1km          10008 non-null  float64
#  51  Hawker_Within_2km          13483 non-null  float64
#  52  hawker_food_stalls         16737 non-null  int64
#  53  hawker_market_stalls       16737 non-null  int64
#  54  mrt_nearest_distance       16737 non-null  float64
#  55  mrt_name                   16737 non-null  object
#  56  bus_interchange            16737 non-null  bool
#  57  mrt_interchange            16737 non-null  bool
#  58  mrt_latitude               16737 non-null  float64
#  59  mrt_longitude              16737 non-null  float64
#  60  bus_stop_nearest_distance  16737 non-null  float64
#  61  bus_stop_name              16737 non-null  object
#  62  bus_stop_latitude          16737 non-null  float64
#  63  bus_stop_longitude         16737 non-null  float64
#  64  pri_sch_nearest_distance   16737 non-null  float64
#  65  pri_sch_name               16737 non-null  object
#  66  vacancy                    16737 non-null  int64
#  67  pri_sch_affiliation        16737 non-null  bool
#  68  pri_sch_latitude           16737 non-null  float64
#  69  pri_sch_longitude          16737 non-null  float64
#  70  sec_sch_nearest_dist       16737 non-null  float64
#  71  sec_sch_name               16737 non-null  object
#  72  cutoff_point               16737 non-null  int64
#  73  affiliation                16737 non-null  bool
#  74  sec_sch_latitude           16737 non-null  float64
#  75  sec_sch_longitude          16737 non-null  float64
# dtypes: bool(9), datetime64[ns](1), float64(24), int64(28), object(14)
# memory usage: 8.7+ MB

# %% [markdown]
# Datatypes are reflected correctly, except `postal` which will be dropped so need not be corrected.

# %% [markdown]
# #### Rename columns when necessary

# %%
# Rename columns
housing_test.rename(columns={"Tranc_YearMonth": "tranc_year_month", 
                        "lease_commence_date": "lease_commence_year", 
                        "Tranc_Year": "tranc_year",
                        "Tranc_Month": "tranc_month",
                        "lower": "lower_storey_range",
                        "upper": "upper_storey_range",
                        "mid": "mid_storey_range",
                        "1room_sold": "1room_res",
                        "2room_sold": "2room_res",
                        "3room_sold": "3room_res",
                        "4room_sold": "4room_res",
                        "5room_sold": "5room_res",
                        "exec_sold": "exec_res",
                        "multigen_sold": "multigen_res",
                        "studio_apartment_sold": "studio_res",
                        "Latitude": "latitude",
                        "Longitude": "longitude",
                        "Mall_Nearest_Distance": "mall_nearest_distance",
                        "Mall_Within_500m": "mall_500m",
                        "Mall_Within_1km": "mall_1km",
                        "Mall_Within_2km": "mall_2km",
                        "Hawker_Nearest_Distance": "hawker_nearest_distance",
                        "Hawker_Within_500m": "hawker_500m",
                        "Hawker_Within_1km": "hawker_1km",
                        "Hawker_Within_2km": "hawker_2km",
                        "hawker_food_stalls": "hawker_stalls",
                        "bus_interchange": "mrt_bus_interchange"
                        }, inplace=True)
housing_test.head(2)
# Out:
#        id tranc_year_month         town flat_type block        street_name  \
# 0  114982       2012-11-01       YISHUN    4 ROOM   173       YISHUN AVE 7
# 1   95653       2019-08-01  JURONG WEST    5 ROOM  986C  JURONG WEST ST 93
#
#   storey_range  floor_area_sqm         flat_model  lease_commence_year  ...  \
# 0     07 TO 09            84.0         Simplified                 1987  ...
# 1     04 TO 06           112.0  Premium Apartment                 2008  ...
#
#    vacancy  pri_sch_affiliation  pri_sch_latitude  pri_sch_longitude  \
# 0       92                False          1.433681         103.832924
# 1       45                False          1.339244         103.698896
#
#    sec_sch_nearest_dist                    sec_sch_name cutoff_point  \
# 0            156.322353  Ahmad Ibrahim Secondary School          218
# 1            739.371688    Jurong West Secondary School          199
#
#   affiliation  sec_sch_latitude  sec_sch_longitude
# 0       False          1.436235         103.829987
# 1       False          1.335256         103.702098
#
# [2 rows x 76 columns]

# %% [markdown]
# #### Check for missing values and datatype

# %%
# Replace null values in 'mall_500m', 'mall_1km', 'mall_2km' with 0
housing_test['mall_500m'] = housing_test['mall_500m'].fillna(0)
housing_test['mall_1km'] = housing_test['mall_1km'].fillna(0)
housing_test['mall_2km'] = housing_test['mall_2km'].fillna(0)

# %%
# Replace null values in 'hawker_500m', 'hawker_1km', 'hawker_2km' with 0
housing_test['hawker_500m'] = housing_test['hawker_500m'].fillna(0)
housing_test['hawker_1km'] = housing_test['hawker_1km'].fillna(0)
housing_test['hawker_2km'] = housing_test['hawker_2km'].fillna(0)

# %%
# Change datatype to reflect columns correctly
housing_test = housing_test.astype({'mall_500m':'int', 'mall_1km':'int', 'mall_2km':'int', 'hawker_500m':'int', 'hawker_1km':'int', 'hawker_2km':'int'})
housing_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16737 entries, 0 to 16736
# Data columns (total 76 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         16737 non-null  int64
#  1   tranc_year_month           16737 non-null  datetime64[ns]
#  2   town                       16737 non-null  object
#  3   flat_type                  16737 non-null  object
#  4   block                      16737 non-null  object
#  5   street_name                16737 non-null  object
#  6   storey_range               16737 non-null  object
#  7   floor_area_sqm             16737 non-null  float64
#  8   flat_model                 16737 non-null  object
#  9   lease_commence_year        16737 non-null  int64
#  10  tranc_year                 16737 non-null  int64
#  11  tranc_month                16737 non-null  int64
#  12  mid_storey                 16737 non-null  int64
#  13  lower_storey_range         16737 non-null  int64
#  14  upper_storey_range         16737 non-null  int64
#  15  mid_storey_range           16737 non-null  int64
#  16  full_flat_type             16737 non-null  object
#  17  address                    16737 non-null  object
#  18  floor_area_sqft            16737 non-null  float64
#  19  hdb_age                    16737 non-null  int64
#  20  max_floor_lvl              16737 non-null  int64
#  21  year_completed             16737 non-null  int64
#  22  residential                16737 non-null  bool
#  23  commercial                 16737 non-null  bool
#  24  market_hawker              16737 non-null  bool
#  25  multistorey_carpark        16737 non-null  bool
#  26  precinct_pavilion          16737 non-null  bool
#  27  total_dwelling_units       16737 non-null  int64
#  28  1room_res                  16737 non-null  int64
#  29  2room_res                  16737 non-null  int64
#  30  3room_res                  16737 non-null  int64
#  31  4room_res                  16737 non-null  int64
#  32  5room_res                  16737 non-null  int64
#  33  exec_res                   16737 non-null  int64
#  34  multigen_res               16737 non-null  int64
#  35  studio_res                 16737 non-null  int64
#  36  1room_rental               16737 non-null  int64
#  37  2room_rental               16737 non-null  int64
#  38  3room_rental               16737 non-null  int64
#  39  other_room_rental          16737 non-null  int64
#  40  postal                     16737 non-null  object
#  41  latitude                   16737 non-null  float64
#  42  longitude                  16737 non-null  float64
#  43  planning_area              16737 non-null  object
#  44  mall_nearest_distance      16653 non-null  float64
#  45  mall_500m                  16737 non-null  int64
#  46  mall_1km                   16737 non-null  int64
#  47  mall_2km                   16737 non-null  int64
#  48  hawker_nearest_distance    16737 non-null  float64
#  49  hawker_500m                16737 non-null  int64
#  50  hawker_1km                 16737 non-null  int64
#  51  hawker_2km                 16737 non-null  int64
#  52  hawker_stalls              16737 non-null  int64
#  53  hawker_market_stalls       16737 non-null  int64
#  54  mrt_nearest_distance       16737 non-null  float64
#  55  mrt_name                   16737 non-null  object
#  56  mrt_bus_interchange        16737 non-null  bool
#  57  mrt_interchange            16737 non-null  bool
#  58  mrt_latitude               16737 non-null  float64
#  59  mrt_longitude              16737 non-null  float64
#  60  bus_stop_nearest_distance  16737 non-null  float64
#  61  bus_stop_name              16737 non-null  object
#  62  bus_stop_latitude          16737 non-null  float64
#  63  bus_stop_longitude         16737 non-null  float64
#  64  pri_sch_nearest_distance   16737 non-null  float64
#  65  pri_sch_name               16737 non-null  object
#  66  vacancy                    16737 non-null  int64
#  67  pri_sch_affiliation        16737 non-null  bool
#  68  pri_sch_latitude           16737 non-null  float64
#  69  pri_sch_longitude          16737 non-null  float64
#  70  sec_sch_nearest_dist       16737 non-null  float64
#  71  sec_sch_name               16737 non-null  object
#  72  cutoff_point               16737 non-null  int64
#  73  affiliation                16737 non-null  bool
#  74  sec_sch_latitude           16737 non-null  float64
#  75  sec_sch_longitude          16737 non-null  float64
# dtypes: bool(9), datetime64[ns](1), float64(18), int64(34), object(14)
# memory usage: 8.7+ MB

# %% [markdown]
# #### Drop unnecessary columns

# %%
# Drop unnecessary columns
housing_test.drop(['id', 'tranc_year_month', 'block', 'street_name', 'address', 'full_flat_type', 'mid_storey', 'residential', 'town', 'bus_stop_name', 'postal', 'mall_nearest_distance'], axis=1, inplace=True)
housing_test.head(2)
# Out:
#   flat_type storey_range  floor_area_sqm         flat_model  \
# 0    4 ROOM     07 TO 09            84.0         Simplified
# 1    5 ROOM     04 TO 06           112.0  Premium Apartment
#
#    lease_commence_year  tranc_year  tranc_month  lower_storey_range  \
# 0                 1987        2012           11                   7
# 1                 2008        2019            8                   4
#
#    upper_storey_range  mid_storey_range  ...  vacancy  pri_sch_affiliation  \
# 0                   9                 8  ...       92                False
# 1                   6                 5  ...       45                False
#
#    pri_sch_latitude  pri_sch_longitude  sec_sch_nearest_dist  \
# 0          1.433681         103.832924            156.322353
# 1          1.339244         103.698896            739.371688
#
#                      sec_sch_name  cutoff_point  affiliation  \
# 0  Ahmad Ibrahim Secondary School           218        False
# 1    Jurong West Secondary School           199        False
#
#    sec_sch_latitude  sec_sch_longitude
# 0          1.436235         103.829987
# 1          1.335256         103.702098
#
# [2 rows x 64 columns]

# %% [markdown]
# ## Save and Export Data

# %%
import os
if not os.path.exists('output'):
    os.makedirs('output')
housing_test.to_csv('output/housing_test.csv', index=False)
